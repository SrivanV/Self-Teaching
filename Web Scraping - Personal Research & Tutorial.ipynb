# %%
import bs4
import lxml
import requests

# %%
# CONSTRUCT A BASIC REQUEST
Res = requests.get('https://www.youtube.com/')

# %%
# OUTPUT THE REQUEST RESULT
#Res.text

# %%
# USE BeautifulSoup TO CREATE AN OBJECT THAT CAN PARSE THROUGH THE REQUEST RESULTS FROM EARLIER
Soup = bs4.BeautifulSoup(Res.text, 'lxml')
#Soup
# Out:
# <!DOCTYPE html>
# <html lang="en" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;"><head><meta content="IE=edge" http-equiv="X-UA-Compatible"/><script nonce="7Ska1gvRxQu7mYyk1bE6+Q">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20210131.08.00');</script><script nonce="7Ska1gvRxQu7mYyk1bE6+Q">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# ...

# %%
# A UNIQUE DATA TYPE FOR THE OBJECT. GOOD TO KEEP IN MIND AS I MOVE FORWARD!
type(Soup)
# Out:
# bs4.BeautifulSoup

# %%
# TEST TO SEE THAT IT'S WORKING
TitleTag = Soup.select('Title')
TitleTag
# Out:
# [<title>YouTube</title>]

# %%
# INSTINCT TOLD ME THAT IT SHOULD JUST BE A STRING BUT THAT'S NOT THE CASE
type(TitleTag)
# Out:
# bs4.element.ResultSet

# %%
# ANOTHER LAYER INTO THE TEST. A RE-AFFIRMATION OF THE FACT THAT IT'S NOT JUST A STRING
TitleTag[0]
# Out:
# <title>YouTube</title>

# %%
# FINAL STEP TO RETREIVE THE ACTUAL STRING THAT I WANTED
TitleTag[0].getText()
# Out:
# 'YouTube'

# %%
# ANOTHER REQUEST TO EXTRACT TEXT FROM A VERY COMMONLY USED WEBSITE LIKE Wikipedia
Res2 = requests.get('https://en.wikipedia.org/wiki/Room_641A')

# %%
# USE THE SAME BASIC CONCEPT FROM EARLIER
Soup2 = bs4.BeautifulSoup(Res2.text, 'lxml')

# %%
# EXTRACT PARTICULAR PARTS OF THE WEBPAGE TO HAVE AN UNDERSTANDING OF HOW TO NAVIGATE THE REQUEST RESULT
Soup2.select('.mw-headline')
# Out:
# [<span class="mw-headline" id="Description">Description</span>,
#  <span class="mw-headline" id="Lawsuits">Lawsuits</span>,
#  <span class="mw-headline" id="Gallery">Gallery</span>,
#  <span class="mw-headline" id="See_also">See also</span>,
#  <span class="mw-headline" id="References">References</span>,
#  <span class="mw-headline" id="External_links">External links</span>]

# %%
# MAKE THE RESULTS MORE VISUALLY READABLE
for Titles in Soup2.select('.mw-headline'):
    print(Titles.text)
# Out:
# Description
# Lawsuits
# Gallery
# See also
# References
# External links

# %%
# A SELF-ASSIGNED TEST TO MAKE SURE THAT I FULLY UNDERSTAND THE CONCEPT.
# MY GOAL IS TO RETREIVE A POPULAR IMAGE ASSOCIATED WITH A VERY MYSTERIOUS CRYPTOGRAPHY CHALLENGE POSTED ONLINE A FEW YEARS AGO
Cicada3301 = requests.get('https://en.wikipedia.org/wiki/Cicada_3301')

# %%
# bs4 OBJECT FOR PARSING
CSoup = bs4.BeautifulSoup(Cicada3301.text, 'lxml')

# %%
# ISOLATE THE IMAGE SECTION
Logo = CSoup.select('.thumbimage')
Logo
# Out:
# [<img alt="" class="thumbimage" data-file-height="246" data-file-width="405" decoding="async" height="134" src="//upload.wikimedia.org/wikipedia/en/thumb/7/7e/Cicada_3301_logo.jpg/220px-Cicada_3301_logo.jpg" srcset="//upload.wikimedia.org/wikipedia/en/thumb/7/7e/Cicada_3301_logo.jpg/330px-Cicada_3301_logo.jpg 1.5x, //upload.wikimedia.org/wikipedia/en/7/7e/Cicada_3301_logo.jpg 2x" width="220"/>,
#  <img alt="" class="thumbimage" data-file-height="661" data-file-width="3961" decoding="async" height="37" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Cicada_3301_poster_locations.png/220px-Cicada_3301_poster_locations.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Cicada_3301_poster_locations.png/330px-Cicada_3301_poster_locations.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Cicada_3301_poster_locations.png/440px-Cicada_3301_poster_locations.png 2x" width="220"/>]

# %%
# CHECK THE CLASS TO DOUBLE CHECK THAT I GRABBED THE RIGHT PORTION
Logo[0]['class']
# Out:
# ['thumbimage']

# %%
# GET THE DIRECT LINK OF THE IMAGE
Logo[0]['src']
# Out:
# '//upload.wikimedia.org/wikipedia/en/thumb/7/7e/Cicada_3301_logo.jpg/220px-Cicada_3301_logo.jpg'

# %%
# PREPENDING THE PROTOCOL IN ORDER TO CREATE A FULL URL
LogoLink = 'http:' + Logo[0]['src']
LogoLink
# Out:
# 'http://upload.wikimedia.org/wikipedia/en/thumb/7/7e/Cicada_3301_logo.jpg/220px-Cicada_3301_logo.jpg'

# %%
# USE THE NOW COMPLETE URL IN ORDER TO DIRECTLY REQUEST THE END GOAL THAT I'M AFTER
Cicada = requests.get(LogoLink, 'lxml')
Cicada
# Out:
# <Response [200]>

# %%
# EXPLORE EXACTLY WHAT WE CALLED BACK FROM THE STEPS I'VE TAKEN SO FAR
# AFTER A BIT OF RESEARCH, I DISCOVERED THAT THE CONENTS ARE INDIVIDUAL PIXEL TAGS THAT NEED TO BE PROCESSED FURTHER
Cicada.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xfe\x00FFile source: https://en.wikipedia.org/wiki/File:Cicada_3301_logo.jpg\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xc0\x00\x0b\x08\x00\x86\x00\xdc\x01\x01"\x00\xff\xc4\x00\x1c\x00\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x06\x07\x05\x04\x03\x08\x02\xff\xc4\x007\x10\x00\x01\x03\x04\x01\x03\x02\x04\x05\x03\x04\x01\x05\x00\x00\x00\x01\x02\x03\x04\x00\x05\x06\x11\x12\x07!1\x13A\x14"Qa\x08\x152q\x81#R\x91$3B\xa1\x17\x16C\x82\xc1\xe1\xff\xda\x00\x08\x01\x01\x00\x00?\x00\xfdSJR\x94\xa5)JR\x94\xa7\xbd)JR\x94\xa5)JR\x94\xa5)JR\x94\xa5)JR\x94\xa5)JR\x94\xa5)JR\x94\xa5)JR\x94\xa5)JR\x94\xa5)JR\x944\xa5(iJR\x94\xa5)\xefJR\x94\xa5)J\x0fzR\x95\x1b\xd5Ss.\xa6\xe2\x18z\xcb7\xdb\xdcf\xa5\xf6\xff\x00J\xd6\xde{\xbf\x8f\x91\x1b#\xf9\x
# ...

# %%
# AGAIN I CONFIRM THAT THE RESULT ABOVE IS NOT THE IMAGE DIRECTLY 
type(Cicada)
# Out:
# requests.models.Response

# %%
# CREATING AN IMAGE THAT I CAN WRITE THE CONTENT OF THE Cicada.content RESULTS  INTO
CicadaLogo = open('Cicada.jpg', 'wb')

# %%
#CALL THE .write FUNCTION IN ORDER TO FINALLY GET MY DESIRED IMAGE 
CicadaLogo.write(Cicada.content)
# Out:
# 5892

# %%
# BE SURE TO CLOSE WHEN DONE WRITING
CicadaLogo.close()

# %% [markdown]
# ### The final result is:
#
# <img src = Cicada.jpg>

# %% [markdown]
# >**IN CONCLUSION, THE IDEA OF WEB SCRAPING IS INVALUABLE AS I'VE ONLY HEARD IT CAN BE IN PROCESSING CONSTANTLY CHANGING WEBPAGES. ADDITIONALLY, BEING ABLE TO ACCESS THE CONTENT THROUGH CODE MAKES IT A VERY USEFUL TOOL SO LONG AS YOU KEEP THE DATATYPES OF THE RESULTS IN MIND WHEN WORKING. FINALLY, MY NEXT GOAL IS TO USE PYTHON TO PROGRAMMATICALLY COLLECT DATA FROM SOCIAL MEDIA WEBSITES IN ORDER TO ANALYZE THE SENTIMENT OF THE USERS DURING MAJOR WORLD EVENTS.**
